# %%
from nltk.corpus.reader.plaintext import CategorizedPlaintextCorpusReader

# %%
DOC_PATTERN = r'(?!\.)[\w_\s]+/[\w\s\d\-]+\.txt'
CAT_PATTERN = r'([\w_\s]+)/.*'

corpus = CategorizedPlaintextCorpusReader(
    '/Users/willard.hong/Documents/learn/learn_fox/atap/corpus', DOC_PATTERN, cat_pattern=CAT_PATTERN
)

# %%
corpus.categories()
# Out:
# ['Star Trek', 'Star Wars']

# %%
corpus.fileids()
# Out:
# ['Star Trek/Star Trek - Balance of Terror.txt',
#  'Star Trek/Star Trek - First Contact.txt',
#  'Star Wars/Star Wars Episode 1.txt',
#  'Star Wars/Star Wars Episode 2.txt']

# %%
#!/usr/bin/env python3

import bs4
import time
import nltk
import pickle
import logging

from nltk.corpus.reader.api import CorpusReader
from nltk.corpus.reader.api import CategorizedCorpusReader

from readability.readability import Unparseable
from readability.readability import Document as Paper
from nltk import pos_tag, sent_tokenize, wordpunct_tokenize

log = logging.getLogger("readability.readability")
log.setLevel('WARNING')

DOC_PATTERN = r'(?!\.)[a-z_\s]+/[a-f0-9]+\.json'
PKL_PATTERN = r'(?!\.)[a-z_\s]+/[a-f0-9]+\.pickle'
CAT_PATTERN = r'([a-z_\s]+)/.*'

TAGS = ['h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'p', 'li']


class PickledCorpusReader(CategorizedCorpusReader, CorpusReader):

    def __init__(self, root, fileids=PKL_PATTERN, **kwargs):
        """
        Initialize the corpus reader.  Categorization arguments
        (``cat_pattern``, ``cat_map``, and ``cat_file``) are passed to
        the ``CategorizedCorpusReader`` constructor.  The remaining arguments
        are passed to the ``CorpusReader`` constructor.
        """
        # Add the default category pattern if not passed into the class.
        if not any(key.startswith('cat_') for key in kwargs.keys()):
            kwargs['cat_pattern'] = CAT_PATTERN

        CategorizedCorpusReader.__init__(self, kwargs)
        CorpusReader.__init__(self, root, fileids)

    def resolve(self, fileids, categories):
        """
        Returns a list of fileids or categories depending on what is passed
        to each internal corpus reader function. This primarily bubbles up to
        the high level ``docs`` method, but is implemented here similar to
        the nltk ``CategorizedPlaintextCorpusReader``.
        """
        if fileids is not None and categories is not None:
            raise ValueError("Specify fileids or categories, not both")

        if categories is not None:
            return self.fileids(categories)
        return fileids

    def docs(self, fileids=None, categories=None):
        """
        Returns the document loaded from a pickled object for every file in
        the corpus. Similar to the BaleenCorpusReader, this uses a generator
        to acheive memory safe iteration.
        """
        # Resolve the fileids and the categories
        fileids = self.resolve(fileids, categories)

        # Create a generator, loading one document into memory at a time.
        for path, enc, fileid in self.abspaths(fileids, True, True):
            with open(path, 'rb') as f:
                yield pickle.load(f)

    def paras(self, fileids=None, categories=None):
        """
        Returns a generator of paragraphs where each paragraph is a list of
        sentences, which is in turn a list of (token, tag) tuples.
        """
        for doc in self.docs(fileids, categories):
            for paragraph in doc:
                yield paragraph

    def sents(self, fileids=None, categories=None):
        """
        Returns a generator of sentences where each sentence is a list of
        (token, tag) tuples.
        """
        for paragraph in self.paras(fileids, categories):
            for sentence in paragraph:
                yield sentence

    def tagged(self, fileids=None, categories=None):
        for sent in self.sents(fileids, categories):
            for token in sent:
                yield token

    def words(self, fileids=None, categories=None):
        """
        Returns a generator of (token, tag) tuples.
        """
        for token in self.tagged(fileids, categories):
            yield token[0]


if __name__ == '__main__':
    from collections import Counter

    corpus = PickledCorpusReader('/Users/willard.hong/Documents/learn/learn_fox/sample')
    words  = Counter(corpus.words())

    print("{:,} vocabulary {:,} word count".format(len(words.keys()), sum(words.values())))
# Out:
# 58,748 vocabulary 1,624,862 word count

# %%
import os
os.path.getsize('/Users/willard.hong/Documents/learn/learn_fox/sample')
# Out:
# 576

# %%
corpus = PickledCorpusReader('/Users/willard.hong/Documents/learn/learn_fox/sample', PKL_PATTERN)

# %%
corpus.readme()
# Out:
# 'Baleen RSS Export\n=================\n\nExported on: May 25, 2016 at 13:26\n373 feeds containing 24,867 posts in 12 categories for 2.3GiB (516M compressed).\n\nCategory Counts\n---------------\n\n- books: 712 (42.5MiB)\n- business: 3725 (375.0MiB)\n- cinema: 1074 (93.7MiB)\n- cooking: 322 (29.6MiB)\n- data_science: 364 (14.9MiB)\n- design: 484 (33.0MiB)\n- do_it_yourself: 1265 (85.4MiB)\n- gaming: 1075 (77.3MiB)\n- news: 11624 (1.2GiB)\n- politics: 1456 (133.3MiB)\n- sports: 1104 (154.4MiB)\n- tech: 1662 (136.7MiB)\n\nBaleen corpus contains 24867 files in 12 categories.\nStructured as:\n    423308 paragraphs (17.023 mean paragraphs per file)\n    734011 sentences (1.734 mean sentences per paragraph).\nWord count of 15987561 with a vocabulary of 177430 (90.106 lexical diversity).\nCorpus scan took 986.645 seconds.\n\nPreprocessing took 33m35.718s\n\nCorpus scan of preprocessed, pickled corpus took 34.567 seconds.\n'

# %%
corpus.categories()
# Out:
# ['books',
#  'business',
#  'cinema',
#  'cooking',
#  'data_science',
#  'design',
#  'do_it_yourself',
#  'gaming',
#  'news',
#  'politics',
#  'sports',
#  'tech']

# %%
corpus.fileids()
# Out:
# ['books/56d86f51c18081104b39adaa.pickle',
#  'books/56d8962bc18081120d8227ed.pickle',
#  'books/56d939bbc1808111c985105f.pickle',
#  'books/56ddce05c1808111c98a2799.pickle',
#  'books/56e1fe20c1808111c98f1dc9.pickle',
#  'books/56e3481ac1808111c990ab50.pickle',
#  'books/56e461b8c1808111c991d1a4.pickle',
#  'books/56e704e7c1808111c994a284.pickle',
#  'books/56e715a7c1808111c994b89a.pickle',
#  'books/56e8466dc1808103936f748d.pickle',
#  'books/56e846dcc1808103936f7526.pickle',
#  'books/56e84718c1808103936f757e.pickle',
#  'books/56e84813c1808103936f7686.pickle',
#  'books/56e84833c1808103936f769f.pickle',
#  'books/56e963e9c1808111e05f5b59.pickle',
#  'books/56ec4421c180814c03c8cef9.pickle',
#  'books/56ec65d7c180814c03c907fa.pickle',
#  'books/56ef7bd4c180814c03cd646e.pickle',
#  'books/56f016f4c1808103e167a7ec.pickle',
#  'books/56f04a0ec1808103e167fd68.pickle',
#  'books/56f53cefc18081352e6553b6.pickle',
#  'books/56fc3a69c18081767c938aad.pickle',
#  'books/56fc3a84c18081767c938b32.pickle',
#  'books/56fc3a89c18081767c938bc4.pickle',
#  'books/56fd9d89c1808103d32d5d23.pickle',
#  'books/57057806c180812e9407f02b.pickle',
#  'books/57058951c180812e940808fa.pickle',
#  'books/57064a12c180812e94096104.pickle',
#  'books/5706a26ec180810ca3948d89.pickle',
#  'books/5706a274c180810ca3948e9d.pickle',
#  'books/57088d9bc180810ca3981838.pickle',
#  'books/5708af37c180810ca398512a.pickle',
#  'books/5708e2cac180810ca398a708.pickle',
#  'books/570d0259c180810ca3a00d6f.pickle',
#  'books/570df80cc180810ca3a1ffc6.pickle',
#  'books/570e3b18c1808103a2789d27.pickle',
#  'books/570e3c1dc1808103a278a7dd.pickle',
#  'books/570e672ac1808109b8319bda.pickle',
#  'books/570eadabc1808109b83230d4.pickle',
#  'books/57100798c1808128a22d9a9f.pickle',
#  'books/57111cc1c1808128a22fb0f9.pickle',
#  'books/57113732c1808128a22fd553.pickle',
#  'books/571493c2c1808128a2345407.pickle',
#  'books/57177a18c1808103a0d1d335.pickle',
#  'books/5717d7e8c1808103a0d26ba0.pickle',
#  'books/571a1e5ac1808103a0d5ef3a.pickle',
#  'books/571a6819c1808103a0d66bb3.pickle',
#  'books/571ded88c1808103a0db7736.pickle',
#  'books/571f4c64c1808103a0dd8d85.pickle',
#  'books/571fc1d9c1808103a0de4b8c.pickle',
#  'books/5721215ac1808103a0e0712b.pickle',
#  'books/57219adac1808103a0e1322d.pickle',
#  'books/5722866fc1808103a0e2a63f.pickle',
#  'books/57233e2cc1808103a0e3aa87.pickle',
#  'books/57239b60c1808103a0e447db.pickle',
#  'books/5728f603c180817cd22b8cc9.pickle',
#  'books/5729f472c180817cd22d0978.pickle',
#  'books/572b104bc180817cd22ec945.pickle',
#  'books/572bb283c180817cd22fcef5.pickle',
#  'books/572ce5fbc180817cd231a902.pickle',
#  'books/572d0034c180817cd231dc58.pickle',
#  'books/5732f388c180817cd23ac411.pickle',
#  'books/5734e8fac180811f3915a7c2.pickle',
#  'books/5737973cc1808103a128a60a.pickle',
#  'books/57399af5c1808103a12c7d73.pickle',
#  'books/573cc672c18081690acd24cf.pickle',
#  'books/573e078ac180810be6e04d07.pickle',
#  'books/573ef60ec180810be6e23093.pickle',
#  'books/573f2a55c180810be6e2ae10.pickle',
#  'books/5741bd83c180810be6e7bf6f.pickle',
#  'books/5745a9c7c180810be6efd70b.pickle',
#  'business/56d625fac1808113ffb877f5.pickle',
#  'business/56d70ab5c180810560aeb7bc.pickle',
#  'business/56d70ad3c180810560aeb87a.pickle',
#  'business/56d72b6fc18081071654e52e.pickle',
#  'business/56d750f3c18081081a6e2261.pickle',
#  'business/56d750f7c18081081a6e2289.pickle',
#  'business/56d750f8c18081081a6e2290.pickle',
#  'business/56d76361c18081084b306835.pickle',
#  'business/56d859c1c18081101b26a913.pickle',
#  'business/56d8a18bc1808111c984596f.pickle',
#  'business/56d9ac0bc1808111c9858ce1.pickle',
#  'business/56d9bccbc1808111c985a1e4.pickle',
#  'business/56d9bccdc1808111c985a266.pickle',
#  'business/56da2042c1808111c98627bc.pickle',
#  'business/56da204cc1808111c9862800.pickle',
#  'business/56da51c7c1808111c9866208.pickle',
#  'business/56db276fc1808111c987405b.pickle',
#  'business/56dbbb81c1808111c987df93.pickle',
#  'business/56dc5015c1808111c98872e4.pickle',
#  'business/56dca275c1808111c988c938.pickle',
#  'business/56dd78b7c1808111c989aedd.pickle',
#  'business/56dd78b7c1808111c989aee5.pickle',
#  'business/56ddcc44c1808111c98a1d0f.pickle',
#  'business/56dddd14c1808111c98a34be.pickle',
#  'business/56de303dc1808111c98a9fd2.pickle',
#  'business/56de823fc1808111c98af600.pickle',
#  'business/56dec3e9c1808111c98b38c6.pickle',
#  'business/56df061fc1808111c98b8959.pickle',
#  'business/56df0621c1808111c98b8995.pickle',
#  'business/56df16cac1808111c98b9fce.pickle',
#  'business/56df2765c1808111c98bb530.pickle',
#  'business/56df5911c1808111c98bf695.pickle',
#  'business/56df8a05c1808111c98c33b4.pickle',
#  'business/56e04f3ec1808111c98d0e9a.pickle',
#  'business/56e04f43c1808111c98d0f35.pickle',
#  'business/56e070b0c1808111c98d3ae3.pickle',
#  'business/56e0f48dc1808111c98ddefe.pickle',
#  'business/56e1a9bbc1808111c98ea6d0.pickle',
#  'business/56e1ba55c1808111c98ebca9.pickle',
#  'business/56e1ba5dc1808111c98ebda2.pickle',
#  'business/56e1caefc1808111c98ed42c.pickle',
#  'business/56e1caf0c1808111c98ed487.pickle',
#  'business/56e21cf6c1808111c98f3e7d.pickle',
#  'business/56e2e26fc1808111c9901cd9.pickle',
#  'business/56e4601ec1808111c991cad6.pickle',
#  'business/56e47088c1808111c991dd3f.pickle',
#  'business/56e47089c1808111c991dd5a.pickle',
#  'business/56e4a1f8c1808111c9921255.pickle',
#  'business/56e4f438c1808111c9926763.pickle',
#  'business/56e577cfc1808111c992e764.pickle',
#  'business/56e5885bc1808111c992f7e4.pickle',
#  'business/56e598d7c1808111c99309b0.pickle',
#  'business/56e5b9cfc1808111c9932cd6.pickle',
#  'business/56e5dad1c1808111c9934f71.pickle',
#  'business/56e64dbec1808111c993c687.pickle',
#  'business/56e6b023c1808111c9942dc3.pickle',
#  'business/56e6c0cbc1808111c9944256.pickle',
#  'business/56e6d150c1808111c99457a9.pickle',
#  'business/56e70334c1808111c994990b.pickle',
#  'business/56e724c0c1808111c994c543.pickle',
#  'business/56e726d9c1808111c994d287.pickle',
#  'business/56e8357bc18081055380f61d.pickle',
#  'business/56e83582c18081055380f66b.pickle',
#  'business/56e837f9c180810553810669.pickle',
#  'business/56e84254c1808103936f6333.pickle',
#  'business/56e85803c1808103936f8087.pickle',
#  'business/56e961e7c1808111e05f5179.pickle',
#  'business/56e96469c1808111e05f624e.pickle',
#  'business/56eab8d6c1808111e05f73af.pickle',
#  'business/56eab8dbc1808111e05f73e8.pickle',
#  'business/56eaca17c180814572d2678e.pickle',
#  'business/56eaca1fc180814572d2688e.pickle',
#  'business/56eadca3c180814572d28a4a.pickle',
#  'business/56eadca3c180814572d28a57.pickle',
#  'business/56ec0025c180814c03c85e57.pickle',
#  'business/56ec0f4ac180814c03c86e5c.pickle',
#  'business/56ec4466c180814c03c8d3af.pickle',
#  'business/56ec5344c180814c03c8e2c6.pickle',
#  'business/56ec7526c180814c03c91b81.pickle',
#  'business/56ec7527c180814c03c91b86.pickle',
#  'business/56ecdd76c180814c03c9be29.pickle',
#  'business/56ed42f2c180814c03ca4246.pickle',
#  'business/56edb5a1c180814c03cae0eb.pickle',
#  'business/56edc64fc180814c03caf947.pickle',
#  'business/56edf849c180814c03cb3e1e.pickle',
#  'business/56ee5c5cc180814c03cbc0f5.pickle',
#  'business/56eeafedc180814c03cc2fd5.pickle',
#  'business/56ef4976c180814c03cd17f8.pickle',
#  'business/56ef8c6dc180814c03cd7657.pickle',
#  'business/56eff349c1808103e1676413.pickle',
#  'business/56f01545c1808103e1679e71.pickle',
#  'business/56f02660c1808103e167bbbc.pickle',
#  'business/56f02662c1808103e167bbe0.pickle',
#  'business/56f0374ac1808103e167d964.pickle',
#  'business/56f439ffc180812db5f4751b.pickle',
#  'business/56f43a0ac180812db5f47556.pickle',
#  'business/56f43a15c180812db5f475d9.pickle',
#  'business/56f54e4dc18081352e656c31.pickle',
#  'business/56f55df7c18081352e657a37.pickle',
#  'business/56f56f9cc18081352e659705.pickle',
#  'business/56f7d0efc1808147f07fe145.pickle',
#  'business/56f805c4c1808147f08040e4.pickle',
#  'business/56f805c5c1808147f080410f.pickle',
#  'business/56f82874c1808147f0807fa3.pickle',
#  'business/56f82a47c1808147f08091a7.pickle',
#  'business/56f92b02c1808147f0824442.pickle',
#  'business/56f92cd6c1808147f08258a4.pickle',
#  'business/56f93c6ec1808147f0826690.pickle',
#  'business/56f93e53c1808147f0827b03.pickle',
#  'business/56f94e54c1808147f0828901.pickle',
#  'business/56f94e5dc1808147f08289db.pickle',
#  'business/56f9504cc1808147f0829f24.pickle',
#  'business/56f97215c1808147f082d293.pickle',
#  'business/56f9be9dc1808147f08376aa.pickle',
#  'business/56fc3805c18081767c937be2.pickle',
#  'business/56fd999dc1808103d32d3f01.pickle',
#  'business/56fd9c76c1808103d32d54ef.pickle',
#  'business/56fdaccec1808103d32d66b1.pickle',
#  'business/56fdaeafc1808103d32d7a4c.pickle',
#  'business/56fdc010c1808103d32d9bca.pickle',
#  'business/56fe5a25c1808103d32e9973.pickle',
#  'business/56fe5bf8c1808103d32eabac.pickle',
#  'business/56fe7db7c1808103d32edb50.pickle',
#  'business/56fea176c1808103d32f22ed.pickle',
#  'business/56feb31fc1808103d32f4709.pickle',
#  'business/56fee8ffc1808103d32fb1e4.pickle',
#  'business/56ff0be0c1808103d32ff4d2.pickle',
#  'business/56ff0be1c1808103d32ff4d4.pickle',
#  'business/56ffdaa0c1808103d33158e0.pickle',
#  'business/57000f4cc1808103d331b77e.pickle',
#  'business/57002277c1808103d331d70b.pickle',
#  'business/570126c5c1808103d3339179.pickle',
#  'business/57017cf0c1808103d3342e25.pickle',
#  'business/5701d4aec1808103d334d74a.pickle',
#  'business/57022b5bc1808103d3356b44.pickle',
#  'business/57024e07c1808103d335a841.pickle',
#  'business/57028215c1808103d33610b7.pickle',
#  'business/570291d0c1808103d3361efe.pickle',
#  'business/570291d6c1808103d3361fd8.pickle',
#  'business/570293c2c1808103d336349a.pickle',
#  'business/57041cebc18081204db7985e.pickle',
#  'business/57041cfec18081204db7994b.pickle',
#  'business/57056cafc180812e9407d032.pickle',
#  'business/57056ccac180812e9407d14a.pickle',
#  'business/57056f97c180812e9407e6c4.pickle',
#  'business/570587aac180812e9407fb14.pickle',
#  'business/57059a5ec180812e94081fc2.pickle',
#  'business/5706039cc180812e9408e4f3.pickle',
#  'business/5706154ec180812e94090095.pickle',
#  'business/570626bfc180812e94091cd1.pickle',
#  'business/5706a039c180810ca39472dc.pickle',
#  'business/5706a03ac180810ca39472ea.pickle',
#  'business/5706b166c180810ca39497be.pickle',
#  'business/5706c35ac180810ca394bb71.pickle',
#  'business/5706c537c180810ca394cf9a.pickle',
#  'business/5706c537c180810ca394cf9c.pickle',
#  'business/5706d6afc180810ca394f283.pickle',
#  'business/57071d8ec180810ca3957332.pickle',
#  'business/57077302c180810ca3960488.pickle',
#  'business/5707eccfc180810ca396f000.pickle',
#  'business/570820a1c180810ca3975b76.pickle',
#  'business/57083038c180810ca3976a5e.pickle',
#  'business/57094856c180810ca3994c73.pickle',
#  'business/570a5b6bc180810ca39b1b40.pickle',
#  'business/570a8f70c180810ca39b76b4.pickle',
#  'business/570ad6a6c180810ca39c039a.pickle',
#  'business/570b3e1ec180810ca39cb2a5.pickle',
#  'business/570bc7cbc180810ca39d9f25.pickle',
#  'business/570bc7ccc180810ca39d9f33.pickle',
#  'business/570bfc78c180810ca39e0953.pickle',
#  'business/570c0dccc180810ca39e2c92.pickle',
#  'business/570c2112c180810ca39e646b.pickle',
#  'business/570c3371c180810ca39e8a2c.pickle',
#  'business/570c44bec180810ca39eacd2.pickle',
#  'business/570c55f2c180810ca39ecec8.pickle',
#  'business/570cbd21c180810ca39f8a7d.pickle',
#  'business/570cdf95c180810ca39fcc2f.pickle',
#  'business/570cef21c180810ca39fdb93.pickle',
#  'business/570cf0fbc180810ca39fef65.pickle',
#  'business/570d243cc180810ca3a0492e.pickle',
#  'business/570d4936c180810ca3a0a983.pickle',
#  'business/570d6a65c180810ca3a0dd9e.pickle',
#  'business/570d8fb8c180810ca3a13a31.pickle',
#  'business/570db08dc180810ca3a16a1b.pickle',
#  'business/570e3b7fc1808103a278a2fb.pickle',
#  'business/570e3b84c1808103a278a332.pickle',
#  'business/570e8922c1808109b831d78a.pickle',
#  'business/570eadd5c1808109b8323660.pickle',
#  'business/570ece5fc1808109b8326923.pickle',
#  'business/5710041dc1808128a22d7e62.pickle',
#  'business/5710041fc1808128a22d7e71.pickle',
#  'business/57101877c1808128a22dbb03.pickle',
#  'business/57103bf4c1808128a22e02e7.pickle',
#  'business/5710d70ac1808128a22f2485.pickle',
#  'business/5710d70fc1808128a22f24cf.pickle',
#  'business/57110954c1808128a22f7c41.pickle',
#  'business/57115205c1808128a22feaf5.pickle',
#  'business/571157f2c1808128a230005e.pickle',
#  'business/57116c81c1808128a230104f.pickle',
#  'business/571187b0c1808128a2303654.pickle',
#  'business/57123186c1808128a2311ae0.pickle',
#  'business/57130f55c1808128a23253c3.pickle',
#  'business/571352fec1808128a232a033.pickle',
#  'business/5713d0c6c1808128a2334e0b.pickle',
#  'business/5713e433c1808128a2335bf9.pickle',
#  'business/57141950c1808128a233add2.pickle',
#  'business/5714dad2c1808128a234b248.pickle',
#  'business/57154635c1808103a0ce7b16.pickle',
#  'business/57155ebcc1808103a0cea111.pickle',
#  'business/57157607c1808103a0cec593.pickle',
#  'business/57164b74c1808103a0d00bf8.pickle',
#  'business/57164b85c1808103a0d00c35.pickle',
#  'business/57165f06c1808103a0d01bc0.pickle',
#  'business/571662fbc1808103a0d03220.pickle',
#  'business/57167686c1808103a0d0420f.pickle',
#  'business/57178ee4c1808103a0d1e8e2.pickle',
#  'business/571792d8c1808103a0d1ff89.pickle',
#  'business/5717bdddc1808103a0d234e3.pickle',
#  'business/5717f0c1c1808103a0d29675.pickle',
#  'business/57180824c1808103a0d2bbaf.pickle',
#  'business/57181f5ec1808103a0d2df13.pickle',
#  'business/571832eec1808103a0d2f0d5.pickle',
#  'business/571849b9c1808103a0d310de.pickle',
#  'business/5718aa6fc1808103a0d3afc6.pickle',
#  'business/5718ecd0c1808103a0d40b44.pickle',
#  'business/5718ecd1c1808103a0d40b49.pickle',
#  'business/5719379ac1808103a0d4975b.pickle',
#  'business/57199087c1808103a0d51789.pickle',
#  'business/5719ed24c1808103a0d59bed.pickle',
#  'business/571a1f8dc1808103a0d5f527.pickle',
#  'business/571a3332c1808103a0d604d5.pickle',
#  'business/571a3332c1808103a0d604d6.pickle',
#  'business/571a629fc1808103a0d6514a.pickle',
#  'business/571a667ec1808103a0d66680.pickle',
#  'business/571a6683c1808103a0d666c4.pickle',
#  'business/571ac3edc1808103a0d6fccf.pickle',
#  'business/571cd557c1808103a0d9dc04.pickle',
#  'business/571d7b18c1808103a0dad3be.pickle',
#  'business/571e30d0c1808103a0dbd5ac.pickle',
#  'business/571e30d1c1808103a0dbd5b9.pickle',
#  'business/571e30d2c1808103a0dbd5cf.pickle',
#  'business/571e34abc1808103a0dbeb3c.pickle',
#  'business/571e34abc1808103a0dbeb49.pickle',
#  'business/571e4835c1808103a0dbfb4f.pickle',
#  'business/571e4c18c1808103a0dc127a.pickle',
#  'business/571e6333c1808103a0dc37c5.pickle',
#  'business/571e8e30c1808103a0dc6d31.pickle',
#  'business/571e8e35c1808103a0dc6dc2.pickle',
#  'business/571ea5a0c1808103a0dc9266.pickle',
#  'business/571f64f2c1808103a0ddb88e.pickle',
#  'business/571f7888c1808103a0ddca41.pickle',
#  'business/571fab89c1808103a0de2cb9.pickle',
#  'business/571fd69dc1808103a0de620a.pickle',
#  'business/571fda75c1808103a0de76bf.pickle',
#  'business/57200760c1808103a0dead96.pickle',
#  'business/572021e8c1808103a0dee65c.pickle',
#  'business/572021eec1808103a0dee6ab.pickle',
#  'business/5720a914c1808103a0dfa33c.pickle',
#  'business/5720c46ac1808103a0dfdcfc.pickle',
#  'business/5720d7fec1808103a0dfef87.pickle',
#  'business/5720d801c1808103a0dfefa6.pickle',
#  'business/5720ef8dc1808103a0e01440.pickle',
#  'business/57210747c1808103a0e039a2.pickle',
#  'business/57211eb0c1808103a0e061fb.pickle',
#  'business/57212286c1808103a0e07744.pickle',
#  'business/572139d1c1808103a0e09cb2.pickle',
#  'business/57222586c1808103a0e20281.pickle',
#  'business/5722694cc1808103a0e263e1.pickle',
#  'business/572280f1c1808103a0e28b36.pickle',
#  'business/5722c7e6c1808103a0e2f890.pickle',
#  'business/572310afc1808103a0e36ce4.pickle',
#  'business/57236dfec1808103a0e3fd1f.pickle',
#  'business/5723858ec1808103a0e42576.pickle',
#  'business/57239c8cc1808103a0e44dec.pickle',
#  'business/57239c91c1808103a0e44e29.pickle',
#  'business/5723b049c1808103a0e45da9.pickle',
#  'business/5723b049c1808103a0e45db2.pickle',
#  'business/5723b04cc1808103a0e45e0a.pickle',
#  'business/5723cb95c1808103a0e4980a.pickle',
#  'business/57240f8cc1808103a0e4f3ab.pickle',
#  'business/572426d5c1808103a0e51584.pickle',
#  'business/57266c8bc1808103a0e87739.pickle',
#  'business/5726c60fc1808103a0e8ef0f.pickle',
#  'business/5726e133c1808103a0e9203b.pickle',
#  'business/572755bac1808103a0e9cdc3.pickle',
#  'business/57278447c1808103a0ea191a.pickle',
#  'business/572797f7c1808103a0ea2a2e.pickle',
#  'business/5727c6afc1808103a0ea778f.pickle',
#  'business/5727ca82c1808103a0ea8c0f.pickle',
#  'business/5727de1fc1808103a0ea9dc8.pickle',
#  'business/5728efc6c180817cd22b70bf.pickle',
#  'business/5729085bc180817cd22b9971.pickle',
#  'business/57290862c180817cd22b9a3c.pickle',
#  'business/57290863c180817cd22b9a4a.pickle',
#  'business/5729374dc180817cd22be6da.pickle',
#  'business/5729374ec180817cd22be6e7.pickle',
#  'business/5729c6cac180817cd22cc851.pickle',
#  'business/5729f5a5c180817cd22d0ffa.pickle',
#  'business/5729f5abc180817cd22d104e.pickle',
#  'business/572a095cc180817cd22d22d2.pickle',
#  'business/572a3875c180817cd22d7122.pickle',
#  'business/572a3c8ac180817cd22d8721.pickle',
#  'business/572a7f5dc180817cd22ddf9c.pickle',
#  'business/572b9c13c180817cd22faba9.pickle',
#  'business/572bafccc180817cd22fbd9a.pickle',
#  'business/572bafd0c180817cd22fbe63.pickle',
#  'business/572c0cfcc180817cd230544f.pickle',
#  'business/572c82f8c180817cd230ffa4.pickle',
#  'business/572c82f9c180817cd230ffcc.pickle',
#  'business/572c82fac180817cd2310020.pickle',
#  'business/572ccb1fc180817cd2317224.pickle',
#  'business/572ccb20c180817cd2317227.pickle',
#  'business/572ccf1fc180817cd23187b9.pickle',
#  'business/572ce354c180817cd2319918.pickle',
#  'business/572cfaa3c180817cd231bf29.pickle',
#  'business/572d76adc180817cd232856e.pickle',
#  'business/572e1701c180817cd23363bd.pickle',
#  'business/572e2e40c180817cd233893b.pickle',
#  'business/572f8e2cc180817cd23587ea.pickle',
#  'business/572fea92c180817cd23611c3.pickle',
#  'business/573018edc180817cd23653fc.pickle',
#  'business/5730a47fc180817cd23720ed.pickle',
#  'business/5730bc15c180817cd237478a.pickle',
#  'business/5730bc18c180817cd2374837.pickle',
#  'business/5730bc19c180817cd2374843.pickle',
#  'business/5730bc1ac180817cd2374850.pickle',
#  'business/5730ef23c180817cd237acc1.pickle',
#  'business/57310336c180817cd237beb1.pickle',
#  'business/5731606dc180817cd238522f.pickle',
#  'business/5731d527c180817cd238ff08.pickle',
#  'business/57320813c180817cd2396040.pickle',
#  'business/57321bc3c180817cd2397284.pickle',
#  'business/57321fa4c180817cd23987ea.pickle',
#  'business/57324e41c180817cd239bf53.pickle',
#  'business/5732a99ec180817cd23a4adc.pickle',
#  'business/5732ee23c180817cd23aaad8.pickle',
#  'business/57333373c180817cd23b1428.pickle',
#  'business/57333751c180817cd23b28a0.pickle',
#  'business/5733a55dc1808103a3efe699.pickle',
#  'business/5733a96ac1808103a3effc2d.pickle',
#  'business/5734e747c180811f3915a22b.pickle',
#  'business/57352a01c180811f39161cc6.pickle',
#  'business/573793acc1808103a1288780.pickle',
#  'business/5737d7c8c1808103a12912ce.pickle',
#  'business/5737f906c1808103a12950af.pickle',
#  'business/57389f2dc1808103a12a8e06.pickle',
#  'business/57394607c1808103a12bd138.pickle',
#  'business/57398a5fc1808103a12c625b.pickle',
#  'business/5739cb52c1808103a12cd6e0.pickle',
#  'business/573a275ec18081690ac7c0ad.pickle',
#  'business/573a38e0c18081690ac7e794.pickle',
#  'business/573a49b6c18081690ac80ba6.pickle',
#  'business/573a4b80c18081690ac82074.pickle',
#  'business/573a7fa3c18081690ac8885c.pickle',
#  'business/573a8ecbc18081690ac8960e.pickle',
#  'business/573b16a8c18081690ac99deb.pickle',
#  'business/573b3915c18081690ac9e777.pickle',
#  'business/573b3915c18081690ac9e779.pickle',
#  'business/573b391cc18081690ac9e857.pickle',
#  'business/573b6c78c18081690aca58a3.pickle',
#  'business/573ba045c18081690acac7eb.pickle',
#  'business/573bc363c18081690acb1099.pickle',
#  'business/573ca25cc18081690acccb2e.pickle',
#  'business/573cb584c18081690acd06a7.pickle',
#  'business/573cc4c0c18081690acd15ef.pickle',
#  'business/573cc69ec18081690acd29cf.pickle',
#  'business/573cd5f4c18081690acd3946.pickle',
#  'business/573cd7ddc18081690acd4ea9.pickle',
#  'business/573ce712c18081690acd5db8.pickle',
#  'business/573e03ffc180810be6e02e51.pickle',
#  'business/573e2935c180810be6e0944b.pickle',
#  'business/573e5bd9c180810be6e0f032.pickle',
#  'business/573f0746c180810be6e25a63.pickle',
#  'business/573f7d48c180810be6e3518f.pickle',
#  'business/573f7f1ec180810be6e366af.pickle',
#  'business/57405977c180810be6e50404.pickle',
#  'business/57417a2ec180810be6e74343.pickle',
#  'business/5741cccdc180810be6e7d3e5.pickle',
#  'business/5741ddc4c180810be6e7f684.pickle',
#  'business/5742fe12c180810be6ea2ee6.pickle',
#  'business/5742ffe8c180810be6ea432d.pickle',
#  'business/574353c3c180810be6eaee97.pickle',
#  'business/5743dc13c180810be6ec0c61.pickle',
#  'business/5744639ec180810be6ed21dc.pickle',
#  'business/574474e3c180810be6ed495a.pickle',
#  'business/5744974ac180810be6ed9512.pickle',
#  'business/5744caecc180810be6ee06d3.pickle',
#  'business/57450ef7c180810be6ee95bb.pickle',
#  'business/5745a812c180810be6efc711.pickle',
#  'cinema/56d629b5c1808113ffb87d8f.pickle',
#  'cinema/56d629bcc1808113ffb87dd3.pickle',
#  'cinema/56d72e85c18081071654ec51.pickle',
#  'cinema/56d84a1ac180810fdcef7548.pickle',
#  'cinema/56da950dc1808111c986aa15.pickle',
#  'cinema/56ddcde8c1808111c98a260e.pickle',
#  'cinema/56df07c4c1808111c98b91e9.pickle',
#  'cinema/56df39b1c1808111c98bd449.pickle',
#  'cinema/56df5aafc1808111c98bfe46.pickle',
#  'cinema/56e0a3ffc1808111c98d8451.pickle',
#  'cinema/56e19ab7c1808111c98e98eb.pickle',
#  'cinema/56e1cc8ec1808111c98edc68.pickle',
#  'cinema/56e1ed99c1808111c98f0732.pickle',
#  'cinema/56e30568c1808111c990520d.pickle',
#  'cinema/56e326aec1808111c9907e09.pickle',
#  'cinema/56e5cbeac1808111c99344be.pickle',
#  'cinema/56e859b8c1808103936f88cb.pickle',
#  'cinema/56eabae5c1808111e05f7ad9.pickle',
#  'cinema/56eade5ec180814572d290fd.pickle',
#  'cinema/56eb0126c180814572d2cb8c.pickle',
#  'cinema/56ec65cdc180814c03c905ab.pickle',
#  'cinema/56ec65cfc180814c03c90628.pickle',
#  'cinema/56ec76c0c180814c03c92148.pickle',
#  'cinema/56ecaa69c180814c03c9748a.pickle',
#  'cinema/56eff4e3c1808103e1676b2a.pickle',
#  'cinema/56f005f2c1808103e16788da.pickle',
#  'cinema/56f038e7c1808103e167dff8.pickle',
#  'cinema/56f04a0bc1808103e167fd12.pickle',
#  'cinema/56f06c36c1808103e16835e7.pickle',
#  'cinema/56f53873c18081352e6542cd.pickle',
#  'cinema/56f5387fc18081352e6542f0.pickle',
#  'cinema/56f53881c18081352e654307.pickle',
#  'cinema/56f85ddbc1808147f080e89f.pickle',
#  'cinema/56f9bde5c1808147f0836fb7.pickle',
#  'cinema/56fdbfe2c1808103d32d96ac.pickle',
#  'cinema/5700c0e4c1808103d332f165.pickle',
#  'cinema/570281d6c1808103d33609a3.pickle',
#  'cinema/5705be91c180812e94086bbe.pickle',
#  'cinema/5706e7c4c180810ca3950d7e.pickle',
#  'cinema/570b0a3cc180810ca39c58bc.pickle',
#  'cinema/570b1b78c180810ca39c7574.pickle',
#  'cinema/570c20dec180810ca39e5d99.pickle',
#  'cinema/570d13dbc180810ca3a030fa.pickle',
#  'cinema/570e671cc1808109b8319a6b.pickle',
#  'cinema/57101850c1808128a22db465.pickle',
#  'cinema/57103bccc1808128a22dfdca.pickle',
#  'cinema/57127cb8c1808128a2318ae2.pickle',
#  'cinema/571508c3c1808128a234f4fe.pickle',
#  'cinema/5715a70ac1808103a0cf1619.pickle',
#  'cinema/571690b2c1808103a0d0768f.pickle',
#  'cinema/5716beaec1808103a0d0be70.pickle',
#  'cinema/5717a8a5c1808103a0d21d48.pickle',
#  'cinema/57190726c1808103a0d43f27.pickle',
#  'cinema/57191ee9c1808103a0d46812.pickle',
#  'cinema/571a9415c1808103a0d6acd3.pickle',
#  'cinema/571aab80c1808103a0d6d40e.pickle',
#  'cinema/571b0876c1808103a0d75ee1.pickle',
#  'cinema/571ea771c1808103a0dc9feb.pickle',
#  'cinema/571ebfbcc1808103a0dcc513.pickle',
#  'cinema/571f7a2ec1808103a0ddd76d.pickle',
#  'cinema/571faa5dc1808103a0de2525.pickle',
#  'cinema/5720f156c1808103a0e0219f.pickle',
#  'cinema/572137a8c1808103a0e09554.pickle',
#  'cinema/572138aac1808103a0e09635.pickle',
#  'cinema/5721522ac1808103a0e0bcdc.pickle',
#  'cinema/57222307c1808103a0e1fa74.pickle',
#  'cinema/57229af6c1808103a0e2bed0.pickle',
#  'cinema/57236bc7c1808103a0e3f4cb.pickle',
#  'cinema/5723c963c1808103a0e49088.pickle',
#  'cinema/57276a63c1808103a0e9eba2.pickle',
#  'cinema/572781fec1808103a0ea110a.pickle',
#  'cinema/572781fec1808103a0ea110b.pickle',
#  'cinema/5729216cc180817cd22bcc7c.pickle',
#  'cinema/57299732c180817cd22c8053.pickle',
#  'cinema/572a23a3c180817cd22d5707.pickle',
#  'cinema/572a6980c180817cd22dc823.pickle',
#  'cinema/572aaf62c180817cd22e34b5.pickle',
#  'cinema/572b6a4ec180817cd22f54d3.pickle',
#  'cinema/572b99d7c180817cd22fa420.pickle',
#  'cinema/572be00ec180817cd2301bc6.pickle',
#  'cinema/572ea6b7c180817cd2344825.pickle',
#  'cinema/573267e3c180817cd239f2ba.pickle',
#  'cinema/57327dd1c180817cd23a1569.pickle',
#  'cinema/57327dd2c180817cd23a1578.pickle',
#  'cinema/57329489c180817cd23a3657.pickle',
#  'cinema/5733a71bc1808103a3eff410.pickle',
#  'cinema/5734e6c4c180811f39159a8f.pickle',
#  'cinema/5734e6c4c180811f39159a96.pickle',
#  'cinema/57358062c180811f3916cb59.pickle',
#  'cinema/573904fcc1808103a12b6031.pickle',
#  'cinema/573a293bc18081690ac7ceab.pickle',
#  'cinema/573c5da7c18081690acc441f.pickle',
#  'cinema/573c910ac18081690accb4d0.pickle',
#  'cinema/573ce8b4c18081690acd6c46.pickle',
#  'cinema/573e0606c180810be6e03d58.pickle',
#  'cinema/573e28fcc180810be6e08d6b.pickle',
#  'cinema/573e4c32c180810be6e0d8f8.pickle',
#  'cinema/573e6e82c180810be6e11f57.pickle',
#  'cinema/573f294dc180810be6e2a03c.pickle',
#  'cinema/57408e5fc180810be6e574c8.pickle',
#  'cooking/56d62b25c1808113ffb8813b.pickle',
#  'cooking/56d62b5dc1808113ffb881be.pickle',
#  'cooking/56d62b7ac1808113ffb88217.pickle',
#  'cooking/56d62b9ac1808113ffb88241.pickle',
#  'cooking/56df4a50c1808111c98bed24.pickle',
#  'cooking/56e40eebc1808111c99179e6.pickle',
#  'cooking/56eacbf1c180814572d273f1.pickle',
#  'cooking/56efbde0c180814c03cdb910.pickle',
#  'cooking/56fc3b5bc18081767c938ea6.pickle',
#  'cooking/56fde293c1808103d32dd68f.pickle',
#  'cooking/56fe7f96c1808103d32eed5e.pickle',
#  'cooking/57012877c1808103d333a0ff.pickle',
#  'cooking/57041f8cc18081204db7ac2f.pickle',
#  'cooking/57041f8ec18081204db7ac6b.pickle',
#  'cooking/5706fac8c180810ca395353e.pickle',
#  'cooking/5706fac8c180810ca395353f.pickle',
#  'cooking/5707c991c180810ca396a582.pickle',
#  'cooking/570ae7dac180810ca39c1f91.pickle',
#  'cooking/5710e85ac1808128a22f4561.pickle',
#  'cooking/57113743c1808128a22fd7fb.pickle',
#  'cooking/57164a5dc1808103a0d00913.pickle',
#  'cooking/57223c8cc1808103a0e22848.pickle',
#  'cooking/5723b30dc1808103a0e46f8a.pickle',
#  'cooking/57279ac5c1808103a0ea3d65.pickle',
#  'cooking/572a3b6cc180817cd22d83fb.pickle',
#  'cooking/57325105c180817cd239d1fd.pickle',
#  'cooking/57379646c1808103a1289a5a.pickle',
#  'cooking/573c6ecfc18081690acc6cd2.pickle',
#  'cooking/573e064ec180810be6e04133.pickle',
#  'cooking/573f0728c180810be6e2575c.pickle',
#  'data_science/56d626b6c1808113ffb87a7c.pickle',
#  'data_science/56d626b6c1808113ffb87a7d.pickle',
#  'data_science/56d626eac1808113ffb87ac7.pickle',
#  'data_science/56d62720c1808113ffb87b47.pickle',
#  'data_science/56ddbb60c1808111c98a09b4.pickle',
#  'data_science/56ddedc1c1808111c98a4f75.pickle',
#  'data_science/56de0f03c1808111c98a7bf4.pickle',
#  'data_science/56e3673cc1808111c990d096.pickle',
#  'data_science/56e835aec18081055380fa02.pickle',
#  'data_science/56e83804c1808105538106b3.pickle',
#  'data_science/56e8426ac1808103936f6734.pickle',
#  'data_science/56ebfe1fc180814c03c85369.pickle',
#  'data_science/56f02678c1808103e167c08e.pickle',
#  'data_science/56f53692c18081352e65402b.pickle',
#  'data_science/56f7d126c1808147f07fe6d3.pickle',
#  'data_science/56f7d128c1808147f07fe703.pickle',
#  'data_science/56f7d12ac1808147f07fe728.pickle',
#  'data_science/56f7d137c1808147f07fe841.pickle',
#  'data_science/56f7d144c1808147f07fe8cd.pickle',
#  'data_science/56f7d148c1808147f07fe901.pickle',
#  'data_science/56f94e7dc1808147f0829562.pickle',
#  'data_science/56fd99fac1808103d32d49ae.pickle',
#  'data_science/5700d098c1808103d3330bc3.pickle',
#  'data_science/5707a4bcc180810ca39652de.pickle',
#  'data_science/5708304ac180810ca3977562.pickle',
#  'data_science/570d1251c180810ca3a02e26.pickle',
#  'data_science/57100471c1808128a22d8992.pickle',
#  'data_science/571016cbc1808128a22db22a.pickle',
#  'data_science/5718ecf5c1808103a0d4160b.pickle',
#  'data_science/571a4aefc1808103a0d62def.pickle',
#  'data_science/571e30eac1808103a0dbe09e.pickle',
#  'data_science/5722216ec1808103a0e1efc5.pickle',
#  'data_science/572ce367c180817cd2319cdf.pickle',
#  'data_science/5730a48dc180817cd2372390.pickle',
#  'data_science/573361fac180817cd23b6dca.pickle',
#  'data_science/573793fcc1808103a12892a8.pickle',
#  'data_science/5737a5dec1808103a128ba4e.pickle',
#  'data_science/57387dd4c1808103a12a5495.pickle',
#  'data_science/573fa072c180810be6e3a720.pickle',
#  'data_science/57425477c180810be6e8ebb1.pickle',
#  'data_science/57454205c180810be6ef0413.pickle',
#  'design/56d62bbec1808113ffb882ff.pickle',
#  'design/56d62bd1c1808113ffb88353.pickle',
#  'design/56d870f7c18081104b39b360.pickle',
#  'design/56d870f9c18081104b39b373.pickle',
#  'design/56d870f9c18081104b39b376.pickle',
#  'design/56dd596ec1808111c98992e2.pickle',
#  'design/56df07e8c1808111c98b96ac.pickle',
#  'design/56df1889c1808111c98bace6.pickle',
#  'design/56e2d38ac1808111c99013d3.pickle',
#  'design/56e43075c1808111c9919f93.pickle',
#  'design/56e579a2c1808111c992f146.pickle',
#  'design/56e690e4c1808111c99413a9.pickle',
#  'design/56e837c9c180810553810477.pickle',
#  'design/56e9643ec1808111e05f5fb5.pickle',
#  'design/56eb0163c180814572d2d001.pickle',
#  'design/56f0060ec1808103e1678ce2.pickle',
#  'design/56f00614c1808103e1678dc8.pickle',
#  'design/56f00614c1808103e1678dde.pickle',
#  'design/56f02827c1808103e167c921.pickle',
#  'design/56f57183c18081352e65a2da.pickle',
#  'design/56f57187c18081352e65a345.pickle',
#  'design/56f7e4e4c1808147f080131a.pickle',
#  'design/56fea34fc1808103d32f36b5.pickle',
#  'design/570270dbc1808103d335ebed.pickle',
#  'design/5702d9fcc1808103d336c139.pickle',
#  'design/5706a236c180810ca39486cf.pickle',
#  'design/57095b51c180810ca3997ced.pickle',
#  'design/570d1423c180810ca3a03661.pickle',
#  'design/57126493c1808128a2316df9.pickle',
#  'design/5715228ec1808128a2351ff9.pickle',
#  'design/571a4db8c1808103a0d63e3a.pickle',
#  'design/571a7ccfc1808103a0d68a4f.pickle',
#  'design/571faa79c1808103a0de2a7c.pickle',
#  'design/57206616c1808103a0df48fa.pickle',
#  'design/57225491c1808103a0e25138.pickle',
#  'design/57226c1ac1808103a0e27711.pickle',
#  'design/5723ca86c1808103a0e495f9.pickle',
#  'design/5727c973c1808103a0ea89e6.pickle',
#  'design/57292295c180817cd22bd12f.pickle',
#  'design/572b53cfc180817cd22f3200.pickle',
#  'design/572b8386c180817cd22f8155.pickle',
#  'design/572ccdfec180817cd23185cd.pickle',
#  'design/572e0276c180817cd2335244.pickle',
#  'design/57308fc4c180817cd2370e97.pickle',
#  'design/5730a74cc180817cd237338f.pickle',
#  'design/5730a74ec180817cd23733d2.pickle',
#  'design/5730ee09c180817cd237aa88.pickle',
#  'design/573364bcc180817cd23b754a.pickle',
#  'design/5734e721c180811f3915a019.pickle',
#  'design/5737964ac1808103a1289a97.pickle',
#  'design/57379651c1808103a1289b78.pickle',
#  'design/57379779c1808103a128a733.pickle',
#  'design/573b3aefc18081690ac9fbca.pickle',
#  'design/573e066dc180810be6e043ae.pickle',
#  'design/573f9010c180810be6e38966.pickle',
#  'do_it_yourself/56d6f637c1808119ebbdf788.pickle',
#  'do_it_yourself/56d845a9c180810fdcef6bce.pickle',
#  'do_it_yourself/56d969c0c1808111c9853b04.pickle',
#  'do_it_yourself/56d97a45c1808111c9854bf8.pickle',
#  'do_it_yourself/56dd36cbc1808111c9896807.pickle',
#  'do_it_yourself/56de92bbc1808111c98b04fd.pickle',
#  'do_it_yourself/56e0c357c1808111c98da5f6.pickle',
#  'do_it_yourself/56e0d3c0c1808111c98dba34.pickle',
#  'do_it_yourself/56e0f488c1808111c98dddcf.pickle',
#  'do_it_yourself/56e1ba51c1808111c98ebc06.pickle',
#  'do_it_yourself/56e20cfac1808111c98f29d3.pickle',
#  'do_it_yourself/56e21cf4c1808111c98f3dee.pickle',
#  'do_it_yourself/56e2d1c4c1808111c9900676.pickle',
#  'do_it_yourself/56e2d1c4c1808111c990067b.pickle',
#  'do_it_yourself/56e324ddc1808111c990748e.pickle',
#  'do_it_yourself/56e4917cc1808111c991ffa9.pickle',
#  'do_it_yourself/56e58859c1808111c992f759.pickle',
#  'do_it_yourself/56e5daccc1808111c9934e7a.pickle',
#  'do_it_yourself/56e83561c18081055380f474.pickle',
#  'do_it_yourself/56eab8b3c1808111e05f71e5.pickle',
#  'do_it_yourself/56eab8b5c1808111e05f71ed.pickle',
#  'do_it_yourself/56eab8bfc1808111e05f726e.pickle',
#  'do_it_yourself/56eadc97c180814572d28810.pickle',
#  'do_it_yourself/56eadc98c180814572d2887e.pickle',
#  'do_it_yourself/56eaff7ac180814572d2c25f.pickle',
#  'do_it_yourself/56edd6efc180814c03cb0ff0.pickle',
#  'do_it_yourself/56ede78bc180814c03cb26ba.pickle',
#  'do_it_yourself/56eeafe7c180814c03cc2ec2.pickle',
#  'do_it_yourself/56ef255ac180814c03ccdbf0.pickle',
#  'do_it_yourself/56efddd7c180814c03cde008.pickle',
#  'do_it_yourself/56f03743c1808103e167d7d3.pickle',
#  'do_it_yourself/56f439ebc180812db5f47457.pickle',
#  'do_it_yourself/56f5360bc18081352e653a58.pickle',
#  'do_it_yourself/56f5812bc18081352e65b240.pickle',
#  'do_it_yourself/56f7d0dac1808147f07fe032.pickle',
#  'do_it_yourself/56f94e4cc1808147f0828824.pickle',
#  'do_it_yourself/56fc37e4c18081767c937a2d.pickle',
#  'do_it_yourself/56fe7dadc1808103d32ed99e.pickle',
#  'do_it_yourself/56feb316c1808103d32f4566.pickle',
#  'do_it_yourself/56fffd75c1808103d331971a.pickle',
#  'do_it_yourself/570079d6c1808103d332704d.pickle',
#  'do_it_yourself/57028026c1808103d335fa3b.pickle',
#  'do_it_yourself/57028027c1808103d335fa9b.pickle',
#  'do_it_yourself/57056ca7c180812e9407cfa5.pickle',
#  'do_it_yourself/57059a59c180812e94081ebb.pickle',
#  'do_it_yourself/570658fdc180812e94096900.pickle',
#  'do_it_yourself/5706c350c180810ca394b9e4.pickle',
#  'do_it_yourself/5707b626c180810ca3966f03.pickle',
#  'do_it_yourself/570ad4d7c180810ca39bf126.pickle',
#  'do_it_yourself/570b3c5cc180810ca39ca27b.pickle',
#  'do_it_yourself/570b7034c180810ca39cf846.pickle',
#  'do_it_yourself/570cef18c180810ca39fda38.pickle',
#  'do_it_yourself/570cef19c180810ca39fda6c.pickle',
#  'do_it_yourself/570d1225c180810ca3a0216e.pickle',
#  'do_it_yourself/570d2432c180810ca3a04797.pickle',
#  'do_it_yourself/570d4750c180810ca3a09303.pickle',
#  'do_it_yourself/57100408c1808128a22d7d66.pickle',
#  'do_it_yourself/57100409c1808128a22d7d69.pickle',
#  'do_it_yourself/5710f7ddc1808128a22f568b.pickle',
#  'do_it_yourself/57116c77c1808128a2300e66.pickle',
#  'do_it_yourself/5712195dc1808128a230fa17.pickle',
#  'do_it_yourself/571322b3c1808128a232611b.pickle',
#  'do_it_yourself/57136b15c1808128a232bd11.pickle',
#  'do_it_yourself/57145cfbc1808128a233fcff.pickle',
#  'do_it_yourself/5714d5f1c1808128a2349c9e.pickle',
#  'do_it_yourself/5716477fc1808103a0cff4c7.pickle',
#  'do_it_yourself/5716767ec1808103a0d04010.pickle',
#  'do_it_yourself/57168e05c1808103a0d06741.pickle',
#  'do_it_yourself/5716a562c1808103a0d08c3a.pickle',
#  'do_it_yourself/5717ecdfc1808103a0d28040.pickle',
#  'do_it_yourself/57188f87c1808103a0d37953.pickle',
#  'do_it_yourself/571c04b6c1808103a0d8bd9b.pickle',
#  'do_it_yourself/571c1bdbc1808103a0d8e025.pickle',
#  'do_it_yourself/571c4a35c1808103a0d91f09.pickle',
#  'do_it_yourself/571cd552c1808103a0d9daf6.pickle',
#  'do_it_yourself/571d0363c1808103a0da1cfc.pickle',
#  'do_it_yourself/571deaecc1808103a0db69c1.pickle',
#  'do_it_yourself/571e76cbc1808103a0dc4689.pickle',
#  'do_it_yourself/571f901fc1808103a0ddefea.pickle',
#  'do_it_yourself/571f9034c1808103a0ddeff1.pickle',
#  'do_it_yourself/571f904ac1808103a0ddf007.pickle',
#  'do_it_yourself/5720c080c1808103a0dfc678.pickle',
#  'do_it_yourself/57220a0cc1808103a0e1c578.pickle',
#  'do_it_yourself/57220a0ec1808103a0e1c628.pickle',
#  'do_it_yourself/572239acc1808103a0e2133b.pickle',
#  'do_it_yourself/57229852c1808103a0e2af83.pickle',
#  'do_it_yourself/5723b041c1808103a0e45be6.pickle',
#  'do_it_yourself/5723b042c1808103a0e45c42.pickle',
#  'do_it_yourself/57246bdbc1808103a0e57383.pickle',
#  'do_it_yourself/5725987ec1808103a0e7347d.pickle',
#  'do_it_yourself/57267ff1c1808103a0e8863d.pickle',
#  'do_it_yourself/57269835c1808103a0e8a720.pickle',
#  'do_it_yourself/5728efb9c180817cd22b7000.pickle',
#  'do_it_yourself/572a7f57c180817cd22dde3b.pickle',
#  'do_it_yourself/572adc2fc180817cd22e6c19.pickle',
#  'do_it_yourself/572b6890c180817cd22f4526.pickle',
#  'do_it_yourself/572e16fbc180817cd2336286.pickle',
#  'do_it_yourself/572ea424c180817cd2343a48.pickle',
#  'do_it_yourself/573001b3c180817cd236338b.pickle',
#  'do_it_yourself/5730eaf0c180817cd237956d.pickle',
#  'do_it_yourself/5731ecaac180817cd2392317.pickle',
#  'do_it_yourself/5734e4a2c180811f39158a5d.pickle',
#  'do_it_yourself/5734e4a6c180811f39158a75.pickle',
#  'do_it_yourself/5737938dc1808103a12885d1.pickle',
#  'do_it_yourself/5737938ec1808103a12885da.pickle',
#  'do_it_yourself/57379392c1808103a12885ec.pickle',
#  'do_it_yourself/57379393c1808103a12885f0.pickle',
#  'do_it_yourself/5737c723c1808103a128f165.pickle',
#  'do_it_yourself/573a274dc18081690ac7bf61.pickle',
#  'do_it_yourself/573ce70fc18081690acd5d1e.pickle',
#  'do_it_yourself/573e03e6c180810be6e02c8c.pickle',
#  'do_it_yourself/573e03eac180810be6e02ced.pickle',
#  'do_it_yourself/573e03ecc180810be6e02d01.pickle',
#  'do_it_yourself/57413507c180810be6e6b2c2.pickle',
#  'do_it_yourself/5741785ac180810be6e72fe2.pickle',
#  'do_it_yourself/57429809c180810be6e9616c.pickle',
#  'do_it_yourself/57429809c180810be6e9616e.pickle',
#  'do_it_yourself/5742dbf2c180810be6e9e6eb.pickle',
#  'do_it_yourself/574342a7c180810be6eac743.pickle',
#  'do_it_yourself/5743ecf5c180810be6ec2d8e.pickle',
#  'do_it_yourself/5744861cc180810be6ed6e67.pickle',
#  'do_it_yourself/5744dc03c180810be6ee2a2a.pickle',
#  'gaming/56d62654c1808113ffb87938.pickle',
#  'gaming/56d62662c1808113ffb87968.pickle',
#  'gaming/56d6267dc1808113ffb879b9.pickle',
#  'gaming/56d62697c1808113ffb879fb.pickle',
#  'gaming/56d845d6c180810fdcef6e0c.pickle',
#  'gaming/56d85a29c18081101b26ac1a.pickle',
#  'gaming/56d8b22bc1808111c9846ff1.pickle',
#  'gaming/56d8c2dbc1808111c98486a5.pickle',
#  'gaming/56d8c2dfc1808111c984874c.pickle',
#  'gaming/56d8d3a0c1808111c9849b50.pickle',
#  'gaming/56d9fef2c1808111c985fe8b.pickle',
#  'gaming/56da204fc1808111c9862893.pickle',
#  'gaming/56dd4754c1808111c9897aa6.pickle',
#  'gaming/56def59ac1808111c98b7565.pickle',
#  'gaming/56def59dc1808111c98b75d6.pickle',
#  'gaming/56df276dc1808111c98bb6a9.pickle',
#  'gaming/56e11555c1808111c98e01c1.pickle',
#  'gaming/56e2b0dcc1808111c98fe33d.pickle',
#  'gaming/56e3147fc1808111c9906114.pickle',
#  'gaming/56e3250bc1808111c9907774.pickle',
#  'gaming/56e3250cc1808111c99077b6.pickle',
#  'gaming/56e9620fc1808111e05f5345.pickle',
#  'gaming/56eab8ebc1808111e05f7434.pickle',
#  'gaming/56eab8efc1808111e05f743f.pickle',
#  'gaming/56eab8fac1808111e05f749b.pickle',
#  'gaming/56eaca2bc180814572d26982.pickle',
#  'gaming/56eb2192c180814572d2fea7.pickle',
#  'gaming/56ec643ec180814c03c9011a.pickle',
#  'gaming/56eee262c180814c03cc7b93.pickle',
#  'gaming/56f02673c1808103e167bf2b.pickle',
#  'gaming/56f43a6ec180812db5f47705.pickle',
#  'gaming/56f43a82c180812db5f4772e.pickle',
#  'gaming/56f43a8bc180812db5f47767.pickle',
#  'gaming/56f53688c18081352e653e1c.pickle',
#  'gaming/56f56fa4c18081352e6597b1.pickle',
#  'gaming/56f56facc18081352e6597b8.pickle',
#  'gaming/56f56fbdc18081352e65980b.pickle',
#  'gaming/56f5a421c18081352e65ecfb.pickle',
#  'gaming/56f7d106c1808147f07fe2e1.pickle',
#  'gaming/56fc3814c18081767c937c3a.pickle',
#  'gaming/56fc382ac18081767c937c8d.pickle',
#  'gaming/56fea186c1808103d32f24cc.pickle',
#  'gaming/57016c1ec1808103d3341281.pickle',
#  'gaming/57041d1ec18081204db79a13.pickle',
#  'gaming/57041d28c18081204db79a4f.pickle',
#  'gaming/57041d44c18081204db79aed.pickle',
#  'gaming/57056cd0c180812e9407d18b.pickle',
#  'gaming/57056cfbc180812e9407d2de.pickle',
#  'gaming/57059a73c180812e940821fe.pickle',
#  'gaming/5706a041c180810ca394738c.pickle',
#  'gaming/5707820cc180810ca39612b8.pickle',
#  'gaming/5707eaf1c180810ca396dc8d.pickle',
#  'gaming/570a1680c180810ca39aae6e.pickle',
#  'gaming/570a6ce6c180810ca39b3993.pickle',
#  'gaming/570ab213c180810ca39bb719.pickle',
#  'gaming/570bc7d1c180810ca39da018.pickle',
#  'gaming/570beb0cc180810ca39de8df.pickle',
#  'gaming/570bfc82c180810ca39e0bc1.pickle',
#  'gaming/570c0dd8c180810ca39e2d2e.pickle',
#  'gaming/570d1241c180810ca3a02443.pickle',
#  'gaming/570d2442c180810ca3a04a01.pickle',
#  'gaming/570d6a6dc180810ca3a0de8f.pickle',
#  'gaming/570d6a70c180810ca3a0df6d.pickle',
#  'gaming/570ee0c0c1808109b832904d.pickle',
#  'gaming/5710044bc1808128a22d8004.pickle',
#  'gaming/5710044ec1808128a22d8029.pickle',
#  'gaming/57100462c1808128a22d80f3.pickle',
#  'gaming/5714ee74c1808128a234c296.pickle',
#  'gaming/5714ee76c1808128a234c2c4.pickle',
#  'gaming/57150720c1808128a234e8b1.pickle',
#  'gaming/57150727c1808128a234e93d.pickle',
#  'gaming/57154641c1808103a0ce7c06.pickle',
#  'gaming/57154645c1808103a0ce7c6c.pickle',
#  'gaming/5717bde9c1808103a0d236b7.pickle',
#  'gaming/5718be30c1808103a0d3c0c0.pickle',
#  'gaming/571961e8c1808103a0d4cee3.pickle',
#  'gaming/571a9179c1808103a0d6a07e.pickle',
#  'gaming/571ac02ac1808103a0d6eb1c.pickle',
#  'gaming/571b3434c1808103a0d79393.pickle',
#  'gaming/571ebe2ac1808103a0dcb9f9.pickle',
#  'gaming/571f6132c1808103a0dda573.pickle',
#  'gaming/571fa7c1c1808103a0de1908.pickle',
#  'gaming/571fa7c4c1808103a0de1941.pickle',
#  'gaming/572166fac1808103a0e0d715.pickle',
#  'gaming/57217e35c1808103a0e0f786.pickle',
#  'gaming/572239cac1808103a0e21748.pickle',
#  'gaming/57228103c1808103a0e28e6e.pickle',
#  'gaming/5722b098c1808103a0e2d7fe.pickle',
#  'gaming/5723f851c1808103a0e4d32a.pickle',
#  'gaming/5727af9fc1808103a0ea5442.pickle',
#  'gaming/5727afa9c1808103a0ea549a.pickle',
#  'gaming/5727afacc1808103a0ea5546.pickle',
#  'gaming/5727de29c1808103a0ea9f81.pickle',
#  'gaming/5728efefc180817cd22b722e.pickle',
#  'gaming/5728efefc180817cd22b722f.pickle',
#  'gaming/5728eff8c180817cd22b72bd.pickle',
#  'gaming/5728f002c180817cd22b73af.pickle',
#  'gaming/57293753c180817cd22be862.pickle',
#  'gaming/572a38b1c180817cd22d7358.pickle',
#  'gaming/572a5038c180817cd22d9820.pickle',
#  'gaming/572b80b9c180817cd22f705f.pickle',
#  'gaming/572c3b5ac180817cd2309a81.pickle',
#  'gaming/572d12a2c180817cd231e949.pickle',
#  'gaming/572f473dc180817cd23523d3.pickle',
#  'gaming/57308d0cc180817cd236fd50.pickle',
#  'gaming/5730bc20c180817cd2374932.pickle',
#  'gaming/5730eafec180817cd23797f7.pickle',
#  'gaming/57310341c180817cd237c0d2.pickle',
#  'gaming/5731d52fc180817cd23900f1.pickle',
#  'gaming/573361ecc180817cd23b6467.pickle',
#  'gaming/5733a573c1808103a3efe904.pickle',
#  'gaming/5734e4f5c180811f39158d9d.pickle',
#  'gaming/5734e4f9c180811f39158df0.pickle',
#  'gaming/5735194ec180811f3915fd7d.pickle',
#  'gaming/573793d1c1808103a1288822.pickle',
#  'gaming/573a9fc6c18081690ac8b7f3.pickle',
#  'gaming/573b059bc18081690ac97daa.pickle',
#  'gaming/573b16b4c18081690ac9a12d.pickle',
#  'gaming/573c5c15c18081690acc3824.pickle',
#  'gaming/573e0413c180810be6e02f1f.pickle',
#  'gaming/573e3871c180810be6e0a5db.pickle',
#  'gaming/57418947c180810be6e752e1.pickle',
#  'gaming/5743cb2dc180810be6ebec0a.pickle',
#  'gaming/5743ecfec180810be6ec2fe6.pickle',
#  'gaming/5744862ec180810be6ed7214.pickle',
#  'gaming/5744a88fc180810be6edbd84.pickle',
#  'gaming/574563d3c180810be6ef3d48.pickle',
#  'gaming/574585d7c180810be6ef7ffc.pickle',
#  'news/56d62554c1808113ffb87492.pickle',
#  'news/56d6255dc1808113ffb874f0.pickle',
#  'news/56d62570c1808113ffb87557.pickle',
#  'news/56d625abc1808113ffb87625.pickle',
#  'news/56d63a76c1808113ffb8841c.pickle',
#  'news/56d63ae1c1808113ffb886b5.pickle',
#  'news/56d63af0c1808113ffb88745.pickle',
#  'news/56d64c7ac1808115036122b4.pickle',
#  'news/56d64cf2c1808115036125f5.pickle',
#  'news/56d65c2ec1808116aade2f8a.pickle',
#  'news/56d65c7cc1808116aade31db.pickle',
#  'news/56d67ba4c18081170340346e.pickle',
#  'news/56d68aadc18081172beb51c7.pickle',
#  'news/56d6c797c18081189e0f7f37.pickle',
#  'news/56d6d6f4c1808118d117500e.pickle',
#  'news/56d6e677c1808118f8de4438.pickle',
#  'news/56d709eec180810560aeb0cd.pickle',
#  'news/56d70a26c180810560aeb34b.pickle',
#  'news/56d717ccc180810545e5f39e.pickle',
#  'news/56d73d29c18081073f0c83e7.pickle',
#  'news/56d73d2fc18081073f0c8435.pickle',
#  'news/56d73dd4c18081073f0c8824.pickle',
#  'news/56d75003c18081081a6e1b5e.pickle',
#  'news/56d75018c18081081a6e1cbd.pickle',
#  'news/56d7503fc18081081a6e1e15.pickle',
#  'news/56d750abc18081081a6e1f34.pickle',
#  'news/56d762a1c18081084b306101.pickle',
#  'news/56d78891c180810943beb7c4.pickle',
#  'news/56d7889bc180810943beb88c.pickle',
#  'news/56d79bccc18081097fdb1dba.pickle',
#  'news/56d7adc8c1808109b3875fed.pickle',
#  'news/56d7c01ec1808109e958eb2f.pickle',
#  'news/56d81b64c180810f77ae9e01.pickle',
#  'news/56d81bc6c180810f77aea0d5.pickle',
#  'news/56d84525c180810fdcef67a1.pickle',
#  'news/56d8453ec180810fdcef6877.pickle',
#  'news/56d84549c180810fdcef6934.pickle',
#  'news/56d86b99c18081104b399ee0.pickle',
#  'news/56d87fb5c18081104b39b51c.pickle',
#  'news/56d89453c18081120d821801.pickle',
#  'news/56d8a169c1808111c9845219.pickle',
#  'news/56d8a174c1808111c9845559.pickle',
#  'news/56d8c2b3c1808111c98480b4.pickle',
#  'news/56d8c2b3c1808111c98480b8.pickle',
#  'news/56d8c2b3c1808111c98480c0.pickle',
#  'news/56d8c2b5c1808111c9848133.pickle',
#  'news/56d8d381c1808111c98496eb.pickle',
#  'news/56d8e435c1808111c984aa92.pickle',
#  'news/56d8e447c1808111c984ac3a.pickle',
#  'news/56d9055fc1808111c984cf90.pickle',
#  'news/56d9699fc1808111c98538cc.pickle',
#  'news/56d98a9ac1808111c9855982.pickle',
#  'news/56d98a9ac1808111c9855983.pickle',
#  'news/56d98a9bc1808111c98559d1.pickle',
#  'news/56d98ab6c1808111c9855cc1.pickle',
#  'news/56d99b60c1808111c9857165.pickle',
#  'news/56d99b60c1808111c985716e.pickle',
#  'news/56d99b6ec1808111c9857276.pickle',
#  'news/56d9abddc1808111c985841b.pickle',
#  'news/56d9abdec1808111c985846b.pickle',
#  'news/56d9bcb3c1808111c9859e61.pickle',
#  'news/56d9cccfc1808111c985b153.pickle',
#  'news/56d9cd00c1808111c985b518.pickle',
#  'news/56d9ee41c1808111c985e0a6.pickle',
#  ...]

# %%
x = corpus.docs(categories='books')

# %%
for y in corpus.docs(categories='books'):
    print(y)

# %%
import json
with open('/Users/willard.hong/Downloads/baleen-sample-20170817/essays/5994c836df23b703bdec9c2c.json') as json_file:
    data = json.load(json_file)

# %%
print(data)
# Out:
# {'_id': {'$oid': '5994c836df23b703bdec9c2c'}, 'feed': {'$oid': '56e71c0bc180817118d3c9c6'}, 'title': 'Amina Yaqin', 'url': 'http://www.bbc.co.uk/programmes/b090vc1p', 'pubdate': {'$date': 1502920800000}, 'content': '<!DOCTYPE html> <html class="" lang="en-GB" > <head> <!-- Barlesque 3.21.26 --> <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /> <meta name="description" content="  Amina Yaqin reflects on the 70-year legacy of partition as reflected in Pakistani culture.  " /> <meta name="keywords" content="  Amina Yaqin  " />   <title> BBC Radio 3 - The Essay, The Culture of Partition, Amina Yaqin</title>        <meta name="viewport" content="width=device-width, initial-scale=1.0" />  <meta property="fb:admins" content="100004154058350" />    \n<!--[if (gt IE 8) | (IEMobile)]><!-->\n<link rel="stylesheet" href="http://static.bbci.co.uk/frameworks/barlesque/3.21.26/orb/4/style/orb.min.css">\n<!--<![endif]-->\n\n<!--[if (lt IE 9) & (!IEMobile)]>\n<link rel="stylesheet" href="http://static.bbci.co.uk/frameworks/barlesque/3.21.26/orb/4/style/orb-ie.min.css">\n<![endif]-->\n\n  <link rel="stylesheet" type="text/css" href="http://static.bbci.co.uk/id/0.37.24/style/id-cta.css"  />  <link rel="stylesheet" type="text/css" href="http://static.bbci.co.uk/id/0.37.24/style/id-cta-v5.css"  />  <link rel="stylesheet" type="text/css" href="http://static.bbci.co.uk/modules/plugin/musicfavourite/3.0.10/style/musicfavourite.min.css"  />  <!--orb.ws.require.lib--> <script class="js-require-lib" src="http://static.bbci.co.uk/frameworks/requirejs/lib.js"></script> <script type="text/javascript">  bbcRequireMap = {"jquery-1":"http://static.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.7.2", "jquery-1.4":"http://static.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.4", "jquery-1.9":"http://static.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.9.1", "jquery-1.12":"http://static.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-1.12.0.min", "jquery-2.2":"http://static.bbci.co.uk/frameworks/jquery/0.4.1/sharedmodules/jquery-2.2.0.min", "istats-1":"//nav.files.bbci.co.uk/nav-analytics/0.1.0-43/js/istats-1", "swfobject-2":"http://static.bbci.co.uk/frameworks/swfobject/0.1.10/sharedmodules/swfobject-2", "demi-1":"http://static.bbci.co.uk/frameworks/demi/0.10.1/sharedmodules/demi-1", "gelui-1":"http://static.bbci.co.uk/frameworks/gelui/0.9.13/sharedmodules/gelui-1", "cssp!gelui-1/overlay":"http://static.bbci.co.uk/frameworks/gelui/0.9.13/sharedmodules/gelui-1/overlay.css", "relay-1":"http://static.bbci.co.uk/frameworks/relay/0.2.6/sharedmodules/relay-1", "clock-1":"http://static.bbci.co.uk/frameworks/clock/0.1.9/sharedmodules/clock-1", "canvas-clock-1":"http://static.bbci.co.uk/frameworks/clock/0.1.9/sharedmodules/canvas-clock-1", "cssp!clock-1":"http://static.bbci.co.uk/frameworks/clock/0.1.9/sharedmodules/clock-1.css", "jssignals-1":"http://static.bbci.co.uk/frameworks/jssignals/0.3.6/modules/jssignals-1", "jcarousel-1":"http://static.bbci.co.uk/frameworks/jcarousel/0.1.10/modules/jcarousel-1", "bump-3":"//emp.bbci.co.uk/emp/bump-3/bump-3", "Amen/Core/Vendor/EQ":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/Amen/Core/Vendor/EQ", "Amen/Core/Vendor/Picturefill":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/Amen/Core/Vendor/Picturefill", "Amen/Core/bootstrap":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/Amen/Core/bootstrap", "Amen/Template/Stream/stream":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/Amen/Template/Stream/stream", "ab":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/ab", "bootstrap":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/bootstrap", "bypass-player-guidance":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/bypass-player-guidance", "carousel":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/carousel", "category-today":"http://static.bbci.co.uk/programmes/2.264.0.27/modules/category-today", "contactform":"http: ...

# %%
import json

# %%
type(data)

# %%
1 + 1
# Out:
# 2
